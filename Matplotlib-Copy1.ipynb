# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Import data csv files
#check if it transfered correctly
mouse_metadata = "Mouse_metadata.csv"
mouse_metadata_df=pd.read_csv(mouse_metadata)
mouse_metadata_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
study_results = "Study_results.csv"
study_results_df=pd.read_csv(study_results)
study_results_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
#Merge datasets - inner merging
complete_df = pd.merge(mouse_metadata_df,study_results_df,on="Mouse ID", how="inner")
complete_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
#Checking total mouse id ( to check for duplication of data) - Step1
complete_df['Mouse ID'].count()
# Out:
# 1893

# %%
#Checking total mouse id ( to check for duplication of data)-Step2
len(complete_df['Mouse ID'].unique())
# Out:
# 249

# %%
#Copy the complete dataframe for getting it ready for clean up
mouse_complete_df=complete_df.copy()
mouse_complete_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
#Make dataframe of duplicate data
duplicate_df=mouse_complete_df.loc[mouse_complete_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
#Make new dataframe without duplicated data of Mouse IDg989
mouse_final_df=mouse_complete_df[mouse_complete_df["Mouse ID"].str.contains("g989")==False]
mouse_final_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
#Check the data after dropping duplicated data. Earlier it was 249, so after dropping g989 it should be 248
len(mouse_final_df['Mouse ID'].unique())
# Out:
# 248

# %%
#calculating statistics summary
mouse_summary_df=mouse_final_df.groupby("Drug Regimen")['Tumor Volume (mm3)'] .aggregate(['mean','median','var','std','sem'])
mouse_summary_df
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
#Renaming summary columns
mouse_summary_df=mouse_summary_df.rename(columns={ 'mean':'Mean Tumor Volume','median':'Median Tumor Volume','var':'Tumor Volume Variance','std':'Tumor Volume Std. Dev.','sem':'Tumor Volume Std. Err.'})
mouse_summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
mouse_summary_df['Mean Tumor Volume']=mouse_summary_df['Mean Tumor Volume'].round(2)
mouse_summary_df["Median Tumor Volume"]=mouse_summary_df['Median Tumor Volume'].round(2)
mouse_summary_df["Tumor Volume Variance"]=mouse_summary_df['Tumor Volume Variance'].round(2)
mouse_summary_df["Tumor Volume Std. Dev."]=mouse_summary_df['Tumor Volume Std. Dev.'].round(2)
mouse_summary_df["Tumor Volume Std. Err."]=mouse_summary_df["Tumor Volume Std. Err."].round(2)
mouse_summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin                 40.68                41.56                  24.95
# Ceftamin                  52.59                51.78                  39.29
# Infubinol                 52.88                51.82                  43.13
# Ketapril                  55.24                53.70                  68.55
# Naftisol                  54.33                52.51                  66.17
# Placebo                   54.03                52.29                  61.17
# Propriva                  52.32                50.45                  43.85
# Ramicane                  40.22                40.67                  23.49
# Stelasyn                  54.23                52.43                  59.45
# Zoniferol                 53.24                51.82                  48.53
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                       4.99                    0.33
# Ceftamin                        6.27                    0.47
# Infubinol                       6.57                    0.49
# Ketapril                        8.28                    0.60
# Naftisol                        8.13                    0.60
# Placebo                         7.82                    0.58
# Propriva                        6.62                    0.54
# Ramicane                        4.85                    0.32
# Stelasyn                        7.71                    0.57
# Zoniferol                       6.97                    0.52

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
drug_groups = mouse_final_df.groupby("Drug Regimen")
total_mice_tested=drug_groups.count()["Timepoint"]
drug_chart = total_mice_tested.plot(kind="bar")
drug_chart.set_xlabel("Drug Regimen")
drug_chart.set_ylabel("Number of Mice Tested")
plt.title("Total Mice Tested For Each Drug Regimen")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
drug_counts=mouse_final_df['Drug Regimen'].value_counts()
drugchart = plt.bar(drug_counts.index.values, drug_counts.values, color="r", align="center")
#drugchart.set_xlabel("Drug Regimen")
#drugchart.set_ylabel("Number of Mice Tested")
#plt.title("Total Mice Tested For Each Drug Regimen")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_groups = mouse_final_df.Sex.value_counts()
Pie_figure1=gender_groups.plot(kind='pie', autopct='%1.1f%%')
plt.title("Distribution of female vs male mice")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using Matplotlib pyplot method
plt.pie(gender_groups,autopct="%1.1f%%",startangle=45)
plt.title("Distribution of female vs male mice")
plt.show()

# %%
#Select dataframe containing four drug regimen, then pick greatest ime point for each mouse
#selected_mouse_df=[mouse_final_df['Drug Regimen']=='Capomulin','Ramicane','Infubinol','Ceftamin']
max_data=mouse_final_df.groupby("Mouse ID").max()['Timepoint']
max_data
#mouse_final_df
# Out:
# Mouse ID
# a203    45
# a251    45
# a262    45
# a275    45
# a366    30
#         ..
# z435    10
# z578    45
# z581    45
# z795    45
# z969    45
# Name: Timepoint, Length: 248, dtype: int64

# %%
max_df=pd.merge(max_data,mouse_final_df,on=['Mouse ID','Timepoint'],how='left')
max_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# 2             70.717621                 4
# 3             62.999356                 3
# 4             63.440686                 1
# ..                  ...               ...
# 243           48.710661                 0
# 244           30.638696                 0
# 245           62.754451                 3
# 246           65.741070                 3
# 247           73.867845                 4
#
# [248 rows x 8 columns]

# %%
#Convert four Drug regimen  list
list_of_treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
list_of_treatments
# Out:
# ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# %%
# Create empty list to fill with tumor vol data 
tumor_vol_list = []
tumor_vol_list
# Out:
# []

# %%
#Fill tumor vol data in empty list
#for i in list_of_treatments:
    #for value in max_df[max_df['Drug Regimen']==i]['Tumor Volume (mm3)'].values:
        #tumor_vol_list.append (value)
#for value in max_df[max_df['Drug Regimen']==i]['Tumor Volume (mm3)'].values:
   #tumor_vol_list.append (value)

# %%
for i in list_of_treatments:
        value=max_df.loc[max_df['Drug Regimen']==i]['Tumor Volume (mm3)']
        tumor_vol_list.append

# %%
tumor_vol_list
# Out:
# []

# %%
#tumor_vol_list2 = []
#tumor_vol_list2

# %%
#Show tumor volume list
#tumor_vol_list

# %%
 # Locate the rows which contain mice on each Capomulin drug and get the tumor volumes
Capomulin = max_df.loc[max_df["Drug Regimen"] == 'Capomulin','Tumor Volume (mm3)']
Capomulin
# Out:
# 19     38.982878
# 24     38.939633
# 61     30.485985
# 64     37.074024
# 66     40.159220
# 80     47.685963
# 83     37.311846
# 85     38.125164
# 87     38.753265
# 108    41.483008
# 115    38.846876
# 121    28.430964
# 124    33.329098
# 162    46.539206
# 163    32.377357
# 169    41.581521
# 174    23.343598
# 180    40.728578
# 183    34.455298
# 192    31.023923
# 204    40.658124
# 208    39.952347
# 220    36.041047
# 226    28.484033
# 239    31.896238
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Locate the rows which contain mice on each Capomulin drug and get the tumor volumes
Ramicane = max_df.loc[max_df["Drug Regimen"] == 'Ramicane','Tumor Volume (mm3)']
Ramicane
# Out:
# 6      38.407618
# 7      43.047543
# 10     38.810366
# 12     32.978522
# 33     38.342008
# 37     33.397653
# 45     37.311236
# 52     40.659006
# 70     29.128472
# 76     33.562402
# 77     36.374510
# 91     31.560470
# 93     36.134852
# 96     22.050126
# 119    30.564625
# 126    31.095335
# 157    45.220869
# 158    36.561652
# 166    37.225650
# 168    43.419381
# 177    30.276232
# 190    40.667713
# 217    43.166373
# 235    44.183451
# 244    30.638696
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Locate the rows which contain mice on each Capomulin drug and get the tumor volumes
Infubinol = max_df.loc[max_df["Drug Regimen"] == 'Infubinol','Tumor Volume (mm3)']
Infubinol
# Out:
# 0      67.973419
# 1      65.525743
# 11     57.031862
# 13     66.083066
# 27     72.226731
# 31     36.321346
# 41     60.969711
# 50     62.435404
# 56     60.918767
# 78     67.289621
# 97     66.196912
# 101    62.117279
# 123    47.010364
# 129    60.165180
# 141    55.629428
# 142    45.699331
# 153    54.656549
# 170    55.650681
# 197    46.250112
# 200    54.048608
# 202    51.542431
# 211    50.005138
# 216    58.268442
# 233    67.685569
# 245    62.754451
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Locate the rows which contain mice on each Capomulin drug and get the tumor volumes
Ceftamin = max_df.loc[max_df["Drug Regimen"] == 'Ceftamin','Tumor Volume (mm3)']
Ceftamin
# Out:
# 3      62.999356
# 21     45.000000
# 22     56.057749
# 25     55.742829
# 58     48.722078
# 75     47.784682
# 88     61.849023
# 94     68.923185
# 106    67.748662
# 107    57.918381
# 109    46.784535
# 110    59.851956
# 113    64.299830
# 134    59.741901
# 150    61.433892
# 154    64.192341
# 184    45.000000
# 188    52.925348
# 189    45.000000
# 209    67.527482
# 223    45.000000
# 228    64.634949
# 231    61.386660
# 238    68.594745
# 240    64.729837
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_vol_list
# Out:
# []

# %%
#Create boxplot
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor volume for various drugs')
ax1.set_ylabel('Final Tumor Volume(mm3)')
ax1.boxplot(tumor_vol_list)
plt.show()

# %%
Figure=plt.boxplot(tumor_vol_list)
plt.show()

# %%
#Determine outliers for drug regimen Capomulin 
quartiles_ca = Capomulin.quantile([.25,.5,.75])
lowerq_ca = quartiles_ca[0.25]
upperq_ca = quartiles_ca[0.75]
#median_ca= quartiles[0.5]
iqr_ca = upperq_ca-lowerq_ca 
#Values below lower_bound could be outliers
lower_bound_ca = lowerq_ca - (1.5*iqr_ca) 
#Values above upper_bound could be outliers.
upper_bound_ca = upperq_ca + (1.5*iqr_ca) 
print(f"Any values above {round(upper_bound_ca,2)} is outlier for final tumor volume in Capomulin drug regimen")
print(f"Any values below {round(lower_bound_ca,2)} is outlier for final tumor volume in Capomulin drug regimen")
# Out:
# Any values above 51.83 is outlier for final tumor volume in Capomulin drug regimen
# Any values below 20.7 is outlier for final tumor volume in Capomulin drug regimen

# %%
#Determine outliers for drug regimen Ramicane 
quartiles_r = Ramicane.quantile([.25,.5,.75])
lowerq_r = quartiles_r[0.25]
upperq_r = quartiles_r[0.75]
#median= quartiles[0.5]
iqr_r = upperq_r-lowerq_r 
#Values below lower_bound could be outliers
lower_bound_r = lowerq_r - (1.5*iqr_r) 
#Values above upper_bound could be outliers.
upper_bound_r = upperq_r + (1.5*iqr_r) 
print(f"Any values above {round(upper_bound_r,2)} is outlier for final tumor volume in Ramicane drug regimen")
print(f"Any values below {round(lower_bound_r,2)} is outlier for final tumor volume in Ramicane drug regimen")
# Out:
# Any values above 54.31 is outlier for final tumor volume in Ramicane drug regimen
# Any values below 17.91 is outlier for final tumor volume in Ramicane drug regimen

# %%
#Determine outliers for drug regimen Infubinol 
quartiles_i = Infubinol.quantile([.25,.5,.75])
lowerq_i = quartiles_i[0.25]
upperq_i = quartiles_i[0.75]
#median= quartiles[0.5]
iqr_i = upperq_i-lowerq_i 
#Values below lower_bound could be outliers
lower_bound_i = lowerq_i - (1.5*iqr_i) 
#Values above upper_bound could be outliers.
upper_bound_i = upperq_i + (1.5*iqr_i) 
print(f"Any values above {round(upper_bound_i,2)} is outlier for final tumor volume in Infubinol drug regimen")
print(f"Any values below {round(lower_bound_i,2)} is outlier for final tumor volume in Infubinol drug regimen")
# Out:
# Any values above 82.74 is outlier for final tumor volume in Infubinol drug regimen
# Any values below 36.83 is outlier for final tumor volume in Infubinol drug regimen

# %%
#Determine outliers for drug regimen Ceftamin  
quartiles_ce = Ceftamin.quantile([.25,.5,.75])
lowerq_ce = quartiles_ce[0.25]
upperq_ce = quartiles_ce[0.75]
#median= quartiles[0.5]
iqr_ce = upperq_ce-lowerq_ce 
#Values below lower_bound could be outliers
lower_bound_ce = lowerq_ce - (1.5*iqr_ce) 
#Values above upper_bound could be outliers.
upper_bound_ce = upperq_ce + (1.5*iqr_ce) 
print(f"Any values above {round(upper_bound_ce,2)} is outlier for final tumor volume in Ceftamin drug regimen")
print(f"Any values below {round(lower_bound_ce,2)} is outlier for final tumor volume in Ceftamin drug regimen")
# Out:
# Any values above 87.67 is outlier for final tumor volume in Ceftamin drug regimen
# Any values below 25.36 is outlier for final tumor volume in Ceftamin drug regimen

# %%
#Creater dataframe with data of Drug Capomulin
cap_drug_df = mouse_final_df.loc[mouse_final_df["Drug Regimen"] == 'Capomulin']
#Select data for one mouse s185
s185_df=cap_drug_df.loc[cap_drug_df["Mouse ID"] == 's185']
s185_df
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0
# 15           33.949940                 0
# 16           32.959671                 1
# 17           28.328531                 1
# 18           25.472143                 1
# 19           23.343598                 1

# %%
# Generate a line plot of tumor volume vs. time point for mouse s185 treated with Capomulin
s185_chart=s185_df.plot('Timepoint', 'Tumor Volume (mm3)')
plt.title('Capomulin treatment of Mouse ID s185')
plt.ylabel('Tumor Volume in (mm3)')
plt.show()
plt.tight_layout()

# %%
cap_drug_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# 11             43.878496                 0
# 12             37.614948                 0
# 13             38.177232                 0
# 14             36.866876                 0
# ...                  ...               ...
# 440            47.685963                 1
# 1452           45.000000                 0
# 1453           45.597064                 0
# 1454           46.059608                 0
# 1455           46.539206                 0
#
# [230 rows x 8 columns]

# %%
# Make dataframe for scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
scatter_df = cap_drug_df.groupby("Mouse ID")
scatter_df= scatter_df['Weight (g)','Tumor Volume (mm3)'].mean()
scatter_df
# Out:
# C:\Users\anjul\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#           Weight (g)  Tumor Volume (mm3)
# Mouse ID
# b128              22           41.963636
# b742              21           40.083699
# f966              17           36.505973
# g288              19           41.990097
# g316              22           44.613344
# i557              24           44.805810
# i738              20           39.141053
# j119              23           44.465236
# j246              21           43.216925
# l509              21           44.434474
# l897              19           42.507261
# m601              17           34.847470
# m957              19           39.049816
# r157              25           45.798970
# r554              17           36.509212
# r944              25           43.367364
# s185              17           34.559143
# s710              23           42.803733
# t565              17           39.328725
# u364              17           39.887495
# v923              21           41.581595
# w150              23           41.384825
# w914              21           41.352452
# x401              15           36.182040
# y793              17           38.506829

# %%
# Scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
plt.scatter(scatter_df['Weight (g)'],scatter_df['Tumor Volume (mm3)']) 
plt.xlabel('Mouse Weight(g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Average tumor volume vs. mouse weight for the Capomulin regimen')
plt.show()

# %%
#Calculate correlation coefficient
correlation=st.pearsonr(scatter_df['Weight (g)'],scatter_df['Tumor Volume (mm3)']) 
print(f"The correlation coefficient between Mouse Weight(g) and Average Tumor Volume (mm3) is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Mouse Weight(g) and Average Tumor Volume (mm3) is 0.84

# %%
#Dependency for regression
from scipy.stats import linregress

# %%
x_values = scatter_df['Weight (g)']
y_values = scatter_df['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 
regress_values = x_values * slope + intercept 
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) 
plt.scatter(x_values,y_values) 
plt.plot(x_values,regress_values,"r-") 
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volumne (mm3)')
plt.title('Average tumor volume vs. mouse weight for the Capomulin regimen')
print(f"The r-squared is: {round(rvalue**2,3)}")
plt.show()
# Out:
# The r-squared is: 0.709
